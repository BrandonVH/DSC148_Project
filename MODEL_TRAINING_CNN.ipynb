# %%
import tensorflow as tf # version 2.18
from tensorflow.python import keras
from keras import layers, callbacks, models # from tensorflow.keras
from keras import preprocessing
from keras import optimizers
# from tensorflow.keras.preprocessing import image_dataset_from_directory
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec
import pandas as pd
import numpy as np

# Reproducability
np.random.seed(31415)
tf.random.set_seed(31415)
os.environ["PYTHONHASHSEED"] = str(31415)
warnings.filterwarnings("ignore") 
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large', titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore")

# %%
train_dir = "/Users/srisupratiktalari/Downloads/train"
valid_dir = "/Users/srisupratiktalari/Downloads/valid"
test_dir = "/Users/srisupratiktalari/Downloads/test"

# %%
# debug
# display a single image

wildfire_dirname = 'nowildfire'

# ./data/cnn_train_data/wildfire/{image name}.jpg

def display_single_image (dir):
    wildfire_dir = os.path.join(dir, wildfire_dirname)
    img_fn = np.random.choice(os.listdir(wildfire_dir))
    img_path = os.path.join(wildfire_dir, img_fn)
    img = preprocessing.image.load_img(img_path)

    plt.imshow(img)
    plt.title(f"{img.size[0]} x {img.size[1]}")

    plt.show()

display_single_image(train_dir) # find image size for image_size parameter for preprocessing.image_dataset_from_directory

# %%
# THIS CODE BLOCK REMOVES IMAGES FROM OUR TRAINING/VALIDATION DATA DIRECTORIES IN THE CASE THAT THEY CAN'T BE DECODED (ONLY NEEDS TO BE RAN ONCE)
# We downloaded the training data as zip files, unzipped them locally by going into file explorer, selecting the files, and clicking "extract all" 

from struct import unpack
from tqdm import tqdm
import os
    
marker_mapping = {
    0xffd8: "Start of Image",
    0xffe0: "Application Default Header",
    0xffdb: "Quantization Table",
    0xffc0: "Start of Frame",
    0xffc4: "Define Huffman Table",
    0xffda: "Start of Scan",
    0xffd9: "End of Image"
}
    
class JPEG:
    def __init__(self, image_file):
        with open(image_file, 'rb') as f:
            self.img_data = f.read()
    
    def decode(self):
        data = self.img_data
        while(True):
            marker, = unpack(">H", data[0:2])
            # print(marker_mapping.get(marker))
            if marker == 0xffd8:
                data = data[2:]
            elif marker == 0xffd9:
                return
            elif marker == 0xffda:
                data = data[-2:]
            else:
                lenchunk, = unpack(">H", data[2:4])
                data = data[2+lenchunk:]            
            if len(data)==0:
                break        
    
bads = []
roots = [
    "/Users/srisupratiktalari/Downloads/train/wildfire",
    "/Users/srisupratiktalari/Downloads/train/nowildfire",
    "/Users/srisupratiktalari/Downloads/valid/wildfire",
    "/Users/srisupratiktalari/Downloads/valid/nowildfire",
    "/Users/srisupratiktalari/Downloads/test/wildfire",
    "/Users/srisupratiktalari/Downloads/test/nowildfire"
]

def bad_images(root_img):
    for img in tqdm(os.listdir(root_img)):
        image_path = os.path.join(root_img, img)
        image = JPEG(image_path)

        try:
            image.decode()
        except:
            bads.append(image_path)

for root_img in roots:
    bad_images(root_img)

for image_path in bads:
    if os.path.exists(image_path):
        os.remove(image_path)

print("Removed bad images:", len(bads))
# Out:
# 100%|██████████| 15750/15750 [00:02<00:00, 6600.94it/s]
# 100%|██████████| 14500/14500 [00:02<00:00, 6253.84it/s]
# 100%|██████████| 3480/3480 [00:00<00:00, 5903.97it/s]
# 100%|██████████| 2820/2820 [00:00<00:00, 5784.91it/s]
# 100%|██████████| 3480/3480 [00:00<00:00, 6300.48it/s]
# 100%|██████████| 2820/2820 [00:00<00:00, 6031.57it/s]
# Removed bad images: 2

# %%
# Load training and validation sets (THIS IS SET TO BINARY RIGHT NOW, BUT WE WANT TO RETURN A NUMERICAL VALUE BETWEEN 0 AND 1 TO REPRESENT RISK)
# WE WILL KEEP IT BINARY FOR NOW JUST TO TEST THE MODEL'S ACCURACY SINCE THE TRAINING DATA IS BINARY
# EVEN THOUGH THE IMAGES ARE 350 by 350 WE CAN JUST MANUALLY CHANGE THE image_size=[width, height] ACCORDINGLY (smaller images = faster training time)
ds_train_ = preprocessing.image_dataset_from_directory("/Users/srisupratiktalari/Downloads/train", labels='inferred', label_mode='binary', image_size=[128, 128], interpolation='nearest', batch_size=32, shuffle=True)
ds_valid_ = preprocessing.image_dataset_from_directory("/Users/srisupratiktalari/Downloads/valid", labels='inferred', label_mode='binary', image_size=[128, 128], interpolation='nearest', batch_size=32, shuffle=False)
# Out:
# Found 30249 files belonging to 2 classes.
# Found 6300 files belonging to 2 classes.

# %%
for i in ds_train_.take(1):
    image = i[0][0].numpy().astype("uint8")

    plt.imshow(image)
    plt.axis("off")
    plt.title(f"Shape: {image.shape}")
    plt.show()
# Out:
# 2026-06-05 18:13:16.207544: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
AUTOTUNE = tf.data.AUTOTUNE

ds_train = (
    ds_train_
    .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
    .cache()
    .prefetch(AUTOTUNE)
)

ds_valid = (
    ds_valid_
    .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
    .cache()
    .prefetch(AUTOTUNE)
)

# %%
#keep in mind there are other preprocessing data augmentation techniques that can be used
model = models.Sequential([
    layers.InputLayer(input_shape=[128, 128, 3]), # 350, 350 references image_size, WHAT DOES 3 REPRESENT? KERNEL_SIZE
    # Data Augmentation (THIS CHANGES OUR TRAINING DATA BY CHANGING THE CONTRAST OF THE IMAGES, FLIPPING THEM, AND ROTATING THEM RANDOMLY. THIS CAN BE HELPFUL FOR BINARY CLASSIFICATION LIKE IDENTIFYING CARS/TRUCKS, BUT NOT FOR CASES WHERE THE COLOR OR POSITION OF IMAGES ARE IMPORTANT)
    # layers.RandomFlip(mode='horizontal'), #preprocessing.RandomFlip()
    # layers.RandomRotation(factor=0.10),
    # Block One
    # layers.BatchNormalization(), # normalizes the data since a consistent distribution makes it easier for the model to find patterns
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'), # the model scans the image according to the kernel_size. 
    #Smaller values mean the model will pick up more distinct patterns, which could lead to overfitting (usually kernel_size is an odd number so there is a single kernel in the middle). 
    #This is a Conv2D layer which scans for a specific feature, which may not always be appropriate for every task. 
    #activation='relu' is used to detect features within the image, and is necessary to allow the model to pick up on non linear patterns 
    #(relevant pixels are labeled with 1, irrelevant pixels are labeled with 0). filters=64 determines how many changes are made to the original image to search for the right pattern.
    layers.MaxPool2D(), # MaxPool2D() removes pixels labeled with 0
    # Block Two
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),
    # Block Three
    layers.BatchNormalization(),
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    #layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'), # WHY ARE THERE 2 Conv2D LAYERS HERE (could lead to overfitting)
    layers.MaxPool2D(),
    # Head
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(8, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid')
])

# optimizer adjusts the weights to minimize the loss, loss measures the disparity between true value and prediction
optimizer = optimizers.Adam(epsilon=0.01, weight_decay=0.0001) # the optimizer applies the activation to the line of best fit to find new patterns ('relu')
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       524,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896,913 (3.42 MB)
#  Trainable params: 896,017 (3.42 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Train CNN model
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=20
)

# Convert training history to a DataFrame
history_df = pd.DataFrame(history.history)

# Plot training and validation loss
history_df[['loss', 'val_loss']].plot(
    title='CNN Training vs Validation Loss'
)

# Plot training and validation accuracy
history_df[['binary_accuracy', 'val_binary_accuracy']].plot(
    title='CNN Training vs Validation Accuracy'
)

# Save trained model
model.save('CNN_WILDFIRE_MODEL.keras')
# Out:
# Epoch 1/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 524s 553ms/step - binary_accuracy: 0.8925 - loss: 0.4051 - val_binary_accuracy: 0.8214 - val_loss: 0.3797
# Epoch 2/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 2372s 3s/step - binary_accuracy: 0.9063 - loss: 0.3155 - val_binary_accuracy: 0.9446 - val_loss: 0.2392
# Epoch 3/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 440s 465ms/step - binary_accuracy: 0.9179 - loss: 0.2640 - val_binary_accuracy: 0.9503 - val_loss: 0.1952
# Epoch 4/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 432s 457ms/step - binary_accuracy: 0.9231 - loss: 0.2376 - val_binary_accuracy: 0.9570 - val_loss: 0.1609
# Epoch 5/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 459s 486ms/step - binary_accuracy: 0.9295 - loss: 0.2163 - val_binary_accuracy: 0.7765 - val_loss: 0.6973
# Epoch 6/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 422s 446ms/step - binary_accuracy: 0.9329 - loss: 0.2047 - val_binary_accuracy: 0.9195 - val_loss: 0.2224
# Epoch 7/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 438s 463ms/step - binary_accuracy: 0.9341 - loss: 0.1939 - val_binary_accuracy: 0.9406 - val_loss: 0.1896
# Epoch 8/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 853s 903ms/step - binary_accuracy: 0.9409 - loss: 0.1816 - val_binary_accuracy: 0.9643 - val_loss: 0.1323
# Epoch 9/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 426s 451ms/step - binary_accuracy: 0.9459 - loss: 0.1635 - val_binary_accuracy: 0.9419 - val_loss: 0.1500
# Epoch 10/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 450s 476ms/step - binary_accuracy: 0.9495 - loss: 0.1546 - val_binary_accuracy: 0.9352 - val_loss: 0.1702
# Epoch 11/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 455s 481ms/step - binary_accuracy: 0.9535 - loss: 0.1393 - val_binary_accuracy: 0.9283 - val_loss: 0.3294
# Epoch 12/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 446s 472ms/step - binary_accuracy: 0.9560 - loss: 0.1342 - val_binary_accuracy: 0.9556 - val_loss: 0.1469
# Epoch 13/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 4470s 5s/step - binary_accuracy: 0.9627 - loss: 0.1170 - val_binary_accuracy: 0.9513 - val_loss: 0.2050
# Epoch 14/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 398s 421ms/step - binary_accuracy: 0.9620 - loss: 0.1179 - val_binary_accuracy: 0.9663 - val_loss: 0.1375
# Epoch 15/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 413s 436ms/step - binary_accuracy: 0.9671 - loss: 0.1031 - val_binary_accuracy: 0.5683 - val_loss: 4.5930
# Epoch 16/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 439s 464ms/step - binary_accuracy: 0.9689 - loss: 0.0970 - val_binary_accuracy: 0.9316 - val_loss: 0.2414
# Epoch 17/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 1327s 1s/step - binary_accuracy: 0.9698 - loss: 0.0909 - val_binary_accuracy: 0.9527 - val_loss: 0.2264
# Epoch 18/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 564s 595ms/step - binary_accuracy: 0.9729 - loss: 0.0827 - val_binary_accuracy: 0.9668 - val_loss: 0.1235
# Epoch 19/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 386s 408ms/step - binary_accuracy: 0.9751 - loss: 0.0796 - val_binary_accuracy: 0.8465 - val_loss: 0.8698
# Epoch 20/20
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 388s 410ms/step - binary_accuracy: 0.9767 - loss: 0.0707 - val_binary_accuracy: 0.9681 - val_loss: 0.1307

# %%
test_data = preprocessing.image_dataset_from_directory('/Users/srisupratiktalari/Downloads/valid"', labels='inferred', label_mode='binary', image_size=[128, 128], interpolation='nearest', batch_size=32, shuffle=True) # confirm cnn_valid_data results match
test_data = (
    test_data
    .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
result = model.evaluate(test_data)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 test_data = preprocessing.image_dataset_from_directory('/Users/srisupratiktalari/Downloads/valid"', labels='inferred', label_mode='binary', image_size=[128, 128], interpolation='nearest', batch_size=32, shuffle=True) # confirm cnn_valid_data results match
#       2 test_data = (
#       3     test_data
#       4     .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
#       5     .cache()
#       6     .prefetch(buffer_size=AUTOTUNE)
#       7 )
#       8 result = model.evaluate(test_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/image_dataset_utils.py:232, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230 if seed is None:
#     231     seed = np.random.randint(1e6)
# --> 232 image_paths, labels, class_names = dataset_utils.index_directory(
#     233     directory,
#     234     labels,
#     235     formats=ALLOWLIST_FORMATS,
#     236     class_names=class_names,
#     237     shuffle=shuffle,
#     238     seed=seed,
#     239     follow_links=follow_links,
#     240     verbose=verbose,
#     241 )
#     243 if label_mode == "binary" and len(class_names) != 2:
#     244     raise ValueError(
#     245         'When passing `label_mode="binary"`, there must be exactly 2 '
#     246         f"class_names. Received: class_names={class_names}"
#     247     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/dataset_utils.py:530, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     528 if labels == "inferred":
#     529     subdirs = []
# --> 530     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     531         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     532             if not subdir.startswith("."):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)    765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory /Users/srisupratiktalari/Downloads/valid"

# %%
# Load the saved CNN model
the_model = models.load_model('CNN_WILDFIRE_MODEL.keras')

# Load test image data
test_data = preprocessing.image_dataset_from_directory(
    './data/cnn_test_data',
    labels='inferred',
    label_mode='binary',
    image_size=(128, 128),
    interpolation='nearest',
    batch_size=32,
    shuffle=False
)

# Apply the same preprocessing used during training
test_data = (
    test_data
    .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# Evaluate the saved model on test data
result = the_model.evaluate(test_data)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[29], line 5
#       2 the_model = models.load_model('CNN_WILDFIRE_MODEL.keras')
#       4 # Load test image data
# ----> 5 test_data = preprocessing.image_dataset_from_directory(
#       6     './data/cnn_test_data',
#       7     labels='inferred',
#       8     label_mode='binary',
#       9     image_size=(128, 128),
#      10     interpolation='nearest',
#      11     batch_size=32,
#      12     shuffle=False
#      13 )
#      15 # Apply the same preprocessing used during training
#      16 test_data = (
#      17     test_data
#      18     .map(lambda image, label: (tf.image.convert_image_dtype(image, tf.float32), label))
#      19     .cache()
#      20     .prefetch(buffer_size=AUTOTUNE)
#      21 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/image_dataset_utils.py:232, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230 if seed is None:
#     231     seed = np.random.randint(1e6)
# --> 232 image_paths, labels, class_names = dataset_utils.index_directory(
#     233     directory,
#     234     labels,
#     235     formats=ALLOWLIST_FORMATS,
#     236     class_names=class_names,
#     237     shuffle=shuffle,
#     238     seed=seed,
#     239     follow_links=follow_links,
#     240     verbose=verbose,
#     241 )
#     243 if label_mode == "binary" and len(class_names) != 2:
#     244     raise ValueError(
#     245         'When passing `label_mode="binary"`, there must be exactly 2 '
#     246         f"class_names. Received: class_names={class_names}"
#     247     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/dataset_utils.py:530, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     528 if labels == "inferred":
#     529     subdirs = []
# --> 530     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     531         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     532             if not subdir.startswith("."):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)    765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory ./data/cnn_test_data

# %%
# DISCLAIMER: THE PATHS USED IN THIS NOTEBOOK WITHIN THE data FOLDER HAVE BEEN DELETED FOR STORAGE PURPOSES
# THE TRAINING DATA FOR THIS MODEL WAS OBTAINED FROM https://www.kaggle.com/datasets/abdelghaniaaba/wildfire-prediction-dataset
